# %% [markdown]
# **Завдання 1.** Ми обговорили з Вами на лекції, що велика літера Сігма грецького алфавіту позначає в математиці суму. Знайдіть з використанням Python $\Sigma x$, $\Sigma x^2$, та $\Sigma (x-1)^2$ для наступного набору даних:
# `1 3 4`
# Виведіть результат кожного обчислення на екран.

# %%
import numpy as np

# %%
# Вхідні дані
data = [1,3,4]
data2 = np.array([1,3,4])

# Обчислення
sum_x = sum(data)
sum_x2 = sum([x**2 for x in data])
sum_x_1_2 = sum((x-1)**2 for x in data)

# Обчислення з numpy
sum_y = np.sum(data2)
sum_y2 = np.sum(data2 ** 2)
sum_y_1_2 = np.sum((data2 -1) ** 2)

#Результат
print("Дані: [1,3,4]")
print("Результат:")
print(f"Σx = {sum_x}")
print(f"Σx² = {sum_x2}")
print(f"Σ(x − 1)² = {sum_x_1_2}")
# Out:
# Дані: [1,3,4]
# Результат:
# Σx = 8
# Σx² = 26
# Σ(x − 1)² = 13

# %% [markdown]
# **Завдання 2.** Ми зібрали дані про суму покупок в гривнях 20ма випадково обраними клієнтами в нашому магазині (всього клієнтів у нас більше) за минулий місяць. Вони представлені в змінній `sum_purchases`. Знайдіть **вибіркове середнє** для цих даних кожним з зазначених методів:
#
#   2.1. без використання жодних бібліотек, користуючись тільки Python.
#   2.2. використовуючи відповідний метод бібліотеки `numpy`.
#
#   Виведіть результат обчислень в кожному з випадків на екран та порівняйте результати. Вони співпадають?

# %%
# Вхідні дані
sum_purchases = [ 316,  493,  367,  153,  224,  121,  322,  450,  196,  397,  281,
  239,  484,  124,  223,  448,  432,  255, 4310, 3524]

# %%
# Обчислення без бібліотек
mean_x = sum(sum_purchases)/len(sum_purchases)

# Обчислення з numpy
mean_y = np.mean(sum_purchases)

#Результат
print("Вибіркове середнє:")
print(f"Без бібліотек (Python): {mean_x:.2f}")
print(f"З використанням NumPy: {mean_y:.2f}")

#Порівняння
if mean_x == mean_y:
  print("Результати співпадають")
else:
  print("Результати не співпадають")
# Out:
# Вибіркове середнє:
# Без бібліотек (Python): 667.95
# З використанням NumPy: 667.95
# Результати співпадають

# %% [markdown]
# **Завдання 3.** Для того ж набору даних в змінній `sum_purchases` обчисліть **медіану** кожним з зазначених методів:
#
#   3.1. без використання жодних бібліотек, користуючись тільки Python.
#   3.2. використовуючи відповідний метод бібліотеки numpy.
#
# Виведіть результат обчислень в кожному з випадків на екран. Порівняйте результати зі значенням вибіркового середнього. Напишіть коментар, для яких задач ви б використовували вибіркове середнє, а для яких - медіану?

# %%
data_sort = sorted(sum_purchases)

# Обчислення без бібліотек
median_data = (data_sort[len(data_sort)//2-1] + data_sort[len(data_sort)//2])/2

# Обчислення з numpy
median_np_data = np.median(data_sort)

#Результат
print("Медіана:")
print(f"Без бібліотек (Python): {median_data:.2f}")
print(f"З використанням NumPy: {median_np_data:.2f}")
# Out:
# Медіана:
# Без бібліотек (Python): 319.00
# З використанням NumPy: 319.00

# %% [markdown]
# У результаті ми бачимо велике відхилення середнього від медіани, бо у наборі даних є два дуже велику значення: 4310 і 3524. Вибіркове середнє я би використовувала у задачах, що стосуються загального доходу магазину, середнього прибутку на клієнта. Медіану - для оцінки поведінки клієнта.

# %% [markdown]
# **Завдання 4**. Обчислість стандартне відхилення наведеної вибірки в змінній `sum_purchases` кожним з зазначених методів:
#
#   4.1. без використання жодних бібліотек, користуючись тільки Python.
#   4.2. використовуючи відповідний метод бібліотеки numpy.
#
# Виведіть результат обчислень в кожному з випадків на екран.

# %%
mean_x = sum(sum_purchases)/len(sum_purchases)
x_minus_mean =  [(el - mean_x)**2 for el in sum_purchases]

# Обчислення без бібліотек
std_dev_sample = np.sqrt(sum(x_minus_mean)/(len(sum_purchases)-1))

# %%
x_minus_mean
# Out:
# [123868.80250000003,
#  30607.502500000017,
#  90570.90250000003,
#  265173.50250000006,
#  197091.60250000004,
#  299154.30250000005,
#  119681.40250000003,
#  47502.20250000002,
#  222736.80250000005,
#  73413.90250000003,
#  149730.30250000005,
#  183998.10250000004,
#  33837.602500000015,
#  295881.60250000004,
#  197980.50250000003,
#  48378.00250000002,
#  55672.40250000002,
#  170527.70250000004,
#  13264528.2025,
#  8157021.602500001]

# %%
# Обчислення з numpy
std_dev_np = np.std(sum_purchases, ddof=1)

#Результат
print("Стандартне відхилення:")
print(f"Без бібліотек (Python): {std_dev_sample:.2f}")
print(f"З використанням NumPy: {std_dev_np:.2f}")
# Out:
# Стандартне відхилення:
# Без бібліотек (Python): 1124.54
# З використанням NumPy: 1124.54

# %% [markdown]
# **Завдання 5**. Ми провели дослідження віку студентів-першокурсників. Виявилось, що
# - 10 студентів мають вік 16 років
# - 25 студентів - 17 років
# - 20 студентів - 18 років
# - 2 студенти - 20 років
#
# Обчислість середнє значення для цієї вибірки будь-яким способом - на чистому Python або з numpy - та виведіть результат на екран.

# %%
# Вхідні дані
students_age = np.array([16]*10 + [17]*25 + [18]*20 + [20]*2)

# %%
# Обчислення
mean_age = np.mean(students_age)

#Результат
print(f"Середній вік студентів-першокурсників: {mean_age:.2f}")
# Out:
# Середній вік студентів-першокурсників: 17.28

# %% [markdown]
# **Завдання 6**. Крім даних про суму покупок, ми зібрали ще дані про кількість відвідувань кожного з кожного покупця, які знаходяться в змінній `visits`. Обчисліть коефіцієнт кореляції Пірсона для суми покупок і кількості відвідувань кожним з зазначених методів:
#
#   6.1. без використання жодних бібліотек, користуючись тільки Python.
#   6.2. використовуючи відповідний метод бібліотеки numpy.
#
# Виведіть результат на екран. Проаналізуйте результат.
#
# Виведіть додатково графік розсіювання викликавши код нижче і зробіть заключення, чи варто щось змінити при підрахунку кореляції, аби коефіцієнт Пірсона показував коректну оцінку лінійної залежності?

# %%
# Додаткові вхідні дані
visits = [ 6,  2, 10,  3,  9,  9,  2,  3,  6,  6, 10,  2,  5, 10,  3,  5,  4,
        7,  4,  2]

# %%
# Обчислення без бібліотек
mean_v = sum(visits)/len(visits)
v_minus_mean = [(el - mean_v)**2 for el in visits]
std_v_sample = np.sqrt(sum(v_minus_mean)/(len(visits)-1))

# %%
xv =  [ (sum_purchases[i] - mean_x)*(visits[i] - mean_v) for i in range(len(sum_purchases))]
cov_xv = sum(xv)/(len(sum_purchases)-1)
r = cov_xv / (std_dev_sample * std_v_sample)
print("Коефіцієнт кореляції Пірсона без бібліотек:", r)
# Out:
# Коефіцієнт кореляції Пірсона без бібліотек: -0.30265844687666454

# %%
# Обчислення з numpy
r_numpy = np.corrcoef(sum_purchases, visits)[0, 1]
print("Коефіцієнт кореляції Пірсона з numpy:", r_numpy)
# Out:
# Коефіцієнт кореляції Пірсона з numpy: -0.3026584468766646

# %%
r2_numpy = np.corrcoef(sum_purchases, visits)

# %%
r2_numpy
# Out:
# array([[ 1.        , -0.30265845],
#        [-0.30265845,  1.        ]])

# %%
import matplotlib.pyplot as plt

plt.scatter(sum_purchases, visits)
plt.title('Scatter Plot of Purchases vs. Visits')
plt.xlabel('Sum of Purchases')
plt.ylabel('Number of Visits');

# %% [markdown]
# Якщо метою є оцінка по звичайним(типовим) клієнтам, то можна видалити або обмежити викиди для того, щоб коефіцієнт Пірсона показував коректну оцінку лінійної залежності.

# %%
import matplotlib.pyplot as plt

plt.scatter(filtered_purchases, filtered_visits)
plt.title('Scatter Plot of Purchases vs. Visits without threshold')
plt.xlabel('Sum of Purchases')
plt.ylabel('Number of Visits');

# %% [markdown]
# **Завдання 7**. В попередньому завданні ми помітили, що викиди нам заважають отримати "правдиве" значення кореляції. Давайте вилучимо записи, які відповідають значенням з викидами в сумі покупок і обчисліть коеф. кореляції. Для цього поставте `threshold`, який дорінює середньому значенню + 2 стандартних вдіхилля суми покупок і всі значення, які більше за нього, будемо вважати викидами (є і інші правила для визначення викидів - з ним и познайомимось пізніше).
#
# Вилучіть значення з обох масивів і обчисліть коеф. кореляції Пірсона з допомогою `numpy` для кількості візитів і суми покупок без записів-викидів. Виведіть результат на екран, побудуйте діаграму розсіювання і проаналізуйте результат: що можемо сказати про залежність в даних?

# %%
# Обчислення викидів
mean_purchases = np.mean(sum_purchases)
std_purchases = np.std(sum_purchases, ddof=1)

threshold = mean_purchases + 2 * std_purchases

# Вилучення викидів
filtered_purchases = []
filtered_visits = []

for i in range(len(sum_purchases)):
    if sum_purchases[i] < threshold:
        filtered_purchases.append(sum_purchases[i])
        filtered_visits.append(visits[i])

# %%
r_filtered = np.corrcoef(filtered_purchases, filtered_visits)[0,1]
print("Коефіцієнт кореляції Пірсона без викидів:", r_filtered)
# Out:
# Коефіцієнт кореляції Пірсона без викидів: -0.3685212078127798

# %%
import matplotlib.pyplot as plt

plt.scatter(filtered_purchases, filtered_visits, color='navy')
plt.title('Scatter Plot of Purchases vs. Visits without thresholds')
plt.xlabel('Sum of Purchases')
plt.ylabel('Number of Visits');

# %% [markdown]
# Між сумою покупок і кількістю відвідувань є помірна негативна лінійна залежність. Тобто, чим більше відвідувань у клієнта, тим менша, в середньому, сума покупки. Але, так як зв'язок не є сильним, багато клієнтів можуть не слідувати цій тенденції.
